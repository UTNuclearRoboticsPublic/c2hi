# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
gesture_obs_results_df = pd.read_csv('../../results/exp0_obs_models/cmd_recognition/gesture_rec_model_accuracy.csv')

# %%
gesture_obs_results_df
# Out:
#     Unnamed: 0 Gesture Time Window      Training Dataset  \
# 0            0         0.5 seconds           Real - Full
# 1            1         0.5 seconds           Real - Full
# 2            2         0.5 seconds           Real - Full
# 3            3         0.5 seconds       Real - Training
# 4            4         0.5 seconds       Real - Training
# 5            5         0.5 seconds       Real - Training
# 6            6         0.5 seconds      Synthetic - Full
# 7            7         0.5 seconds      Synthetic - Full
# 8            8         0.5 seconds      Synthetic - Full
# 9            9         0.5 seconds  Synthetic - Training
# 10          10         0.5 seconds  Synthetic - Training
# 11          11         0.5 seconds  Synthetic - Training
# 12          12         1.0 seconds           Real - Full
# 13          13         1.0 seconds           Real - Full
# 14          14         1.0 seconds           Real - Full
# ...

# %%
invalid_combos = {}
